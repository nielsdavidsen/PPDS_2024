# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# plot with transparent background
plt.plot(x, y, 'r', alpha=0.5, linewidth=2, label='sin(x)')
plt.show()
